# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("stroke_data.csv")
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df1.shape
# Out:
# (5110, 12)

# %%
df1.shape
# Out:
# (5110, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df1.isnull()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here, bmi has null values

# %% [markdown]
# # Visualization of Data

# %% [markdown]
# # 1. Count Plot

# %% [markdown]
# # Gender

# %%
sns.set_style('whitegrid')
sns.countplot(x='gender',data=df1)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# In This data around 3000 are female and 2000 are male

# %%
sns.set_style('whitegrid')
sns.countplot(x ='stroke', hue ='gender', data=df1)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='count'>

# %% [markdown]
# # 2. Hypertension

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="hypertension")
print(df1.hypertension.value_counts())
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %% [markdown]
# # Marriage Status

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="ever_married")
print(df1.ever_married.value_counts())
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %% [markdown]
# # Work Type

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="work_type")
print(df1.work_type.value_counts())
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %% [markdown]
# # Heart Disease

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="heart_disease")
print(df1.heart_disease.value_counts())
# Out:
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64

# %% [markdown]
# # Smoking Status

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="smoking_status")
print(df1.smoking_status.value_counts())
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %% [markdown]
# # Residence type

# %%
sns.set_style('whitegrid')
sns.countplot(data=df1, x="Residence_type")
print(df1.Residence_type.value_counts())
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %% [markdown]
# # Stroke

# %%
sns.set_style('whitegrid')
sns.countplot(x='stroke',data=df1)
print(df1.stroke.value_counts())
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %% [markdown]
#  Here, very few people are suffering from stroke and so this data is very much imbalanced.
#     To balance the data we need to use sampling technique.

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# # Average Glucose Level

# %%
fig = plt.figure(figsize=(8,8))
plt.title('Distribution of Average Glucose Level', fontsize = 25)
sns.distplot(df1.avg_glucose_level, label="avg_glucose_level", kde= False)
plt.legend()

# %% [markdown]
# # No Stroke vs Stroke by Avg. Glucose Level

# %%
plt.figure(figsize=(12,10))

sns.distplot(df1[df1['stroke'] == 0]["avg_glucose_level"], color='green') # No Stroke - green
sns.distplot(df1[df1['stroke'] == 1]["avg_glucose_level"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by Avg. Glucose Level', fontsize=15)
plt.xlim([30,330])
plt.show()
# Out:
# /Users/sharmin/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/sharmin/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # BMI

# %%
fig = plt.figure(figsize=(8,8))
plt.title('Distribution of BMI', fontsize = 25)
sns.distplot(df1.avg_glucose_level, label="bmi", kde= False)
plt.legend()
# Out:
# /Users/sharmin/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # No Stroke vs Stroke by BMI

# %%
plt.figure(figsize=(12,10))

sns.distplot(df1[df1['stroke'] == 0]["bmi"], color='green') # No Stroke - green
sns.distplot(df1[df1['stroke'] == 1]["bmi"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by BMI', fontsize=15)
plt.xlim([10,100])
plt.show()
# Out:
# /Users/sharmin/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/sharmin/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Pair Plot

# %%
fig = plt.figure(figsize=(10,10))
sns.pairplot(df1, hue = 'stroke')
plt.show()

# %%
df1 = df1.drop('id', axis=1) #id column not necessary

# %%
df1.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df1.corr(), annot=True, cmap ="coolwarm")
plt.show()
